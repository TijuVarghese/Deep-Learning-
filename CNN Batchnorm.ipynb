# %% [markdown]
# # Experiment 3
# ## Study the effect of batch normalisation and dropout in neural network classifier

# %%
import tensorflow as tf  
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import Dropout,BatchNormalization

# %% [markdown]
# Load datset

# %%
# Load in the data
cifar10 = tf.keras.datasets.cifar10
 
# Distribute it to train and test set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# ...
# 170508288/170498071 [==============================] - 3s 0us/step
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %% [markdown]
# Image visualization

# %%
fig, ax = plt.subplots(5, 5)
k = 0
 
for i in range(5):
    for j in range(5):
        ax[i][j].imshow(x_train[k], aspect='auto')
        k += 1
 
plt.show()

# %% [markdown]
# Image normalizing

# %%
# Reduce pixel values
x_train, x_test = x_train / 255.0, x_test / 255.0
 

# flatten the label values
y_train, y_test = y_train.flatten(), y_test.flatten()

# %% [markdown]
# Simple CNN model

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(x_train,y_train, epochs=10, 
                    validation_data=(x_test,y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 10)                650
#
# ...
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.5173 - accuracy: 0.4463 - val_loss: 1.2586 - val_accuracy: 0.5516
# Epoch 2/10
# ...

# %% [markdown]
# Visualization of test results

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(x_test,y_test, verbose=2)
print(test_acc)
# Out:
# 313/313 - 4s - loss: 0.8371 - accuracy: 0.7216 - 4s/epoch - 12ms/step
# 0.7215999960899353

# %% [markdown]
# CNN with dropout

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(Dropout(0.25))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(x_train,y_train, epochs=10, 
                    validation_data=(x_test,y_test))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_2 (Dense)             (None, 64)                65600
#
#  dense_3 (Dense)             (None, 10)                650
#
# ...
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# ...

# %% [markdown]
# Visualising results

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(x_test,y_test, verbose=2)
print(test_acc)
# Out:
# 313/313 - 4s - loss: 0.8167 - accuracy: 0.7181 - 4s/epoch - 12ms/step
# 0.7181000113487244

# %% [markdown]
# CNN with Batch normalization

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(BatchNormalization())
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(x_train,y_train, epochs=10, 
                    validation_data=(x_test,y_test))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_4 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  batch_normalization (BatchN  (None, 6, 6, 64)         256
#  ormalization)
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 64)                65600
#
#  dense_5 (Dense)             (None, 10)                650
#
# ...
# Total params: 122,826
# Trainable params: 122,698
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/10
# ...

# %% [markdown]
# Visualising Results

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(x_test,y_test, verbose=2)
print(test_acc)
# Out:
# 313/313 - 4s - loss: 1.0588 - accuracy: 0.6895 - 4s/epoch - 12ms/step
# 0.6894999742507935

# %% [markdown]
# CNN with Dropout and Batch normalization

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(BatchNormalization()) 
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(Dropout(0.25))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(x_train,y_train, epochs=10, 
                    validation_data=(x_test,y_test))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_9 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_6 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 13, 13, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 6, 6, 64)         256
#  hNormalization)
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 64)          36928
#
#  flatten_3 (Flatten)         (None, 1024)              0
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_6 (Dense)             (None, 64)                65600
#
#  dense_7 (Dense)             (None, 10)                650
#
# ...
# Total params: 122,826
# Trainable params: 122,698
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/10
# ...

# %% [markdown]
# Visualising Results

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(x_test,y_test, verbose=2)
print(test_acc)
# Out:
# 313/313 - 5s - loss: 0.8552 - accuracy: 0.7122 - 5s/epoch - 16ms/step
# 0.7121999859809875

# %% [markdown]
# # **RESULTS AND CONCLUSION**
# ###Following are the results of the experiment:
# ![image.png](data:image/png;base64,...)
#
#
# * Based on our observations, in case of CNN model, dropout and batch
# normalization does not improve the testing accuracy of the model.
# * Simple CNN has higher accuracy than models with dropout and batch normalization.
# * We also see that although batch normalization shows 84% accuracy while training the model performs poorly (68%) while testing.
# * This could be a sign of overfitting. Batch normalization has been
# discussed as a remedy for overfitting but in this case, it behaves conversely.

# %% [markdown]
# # Visualization
# ##1)Simple CNN
# ![image.png](data:image/png;base64,...)
# ##2)CNN with dropout
# ![image.png](data:image/png;base64,...)
#
# ##3)CNN with batch normalization
# ![image.png](data:image/png;base64,...)
# ##4)CNN with dropout & batch normalization
# ![image.png](data:image/png;base64,...)
